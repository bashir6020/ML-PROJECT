# %% [markdown]
# <a href="https://colab.research.google.com/github/bashir6020/ML-PROJECT/blob/main/Rock_vs_Mine_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("I am salman")
# Out:
# I am salman

# %%
print("I live Cumilla")
# Out:
# I live Cumilla
